# %% [markdown]
# <a href="https://colab.research.google.com/github/siddu541/Analytics/blob/master/SentimentAnalysisSimpleMobile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (0.22.0)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.5.3)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.14.6)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2->pandas) (1.11.0)
# Requirement already satisfied: tweepy in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.11.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.2.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.6.8)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy) (2.18.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2018.11.29)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Collecting vaderSentiment
#   Downloading https://files.pythonhosted.org/packages/86/9e/c53e1fc61aac5ee490a6ac5e21b1ac04e55a7c2aba647bb8411c9aadf24e/vaderSentiment-3.2.1-py2.py3-none-any.whl (125kB)
#     100% |████████████████████████████████| 133kB 6.1MB/s
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.2.1

# %%
import tweepy
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd

# %%
consumer_key = 'vQZ6khCOPsDeQkY6md7wywU1n' 
consumer_secret='ojflAdoevAAq7SKpoPEifbDfp1sVQ6IXdqX9ZDt5mxHLAkefq9'
access_token='14244512-RquXQtwuWr2RuhUxXJJE9Udtbt9QbyqExhPledJ9Z'
access_token_secret='7fBPW5uEme6lLZJrejSn7jAsExr86H6Zy5cKMrhfYgJos'

# %%
auth=tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)

api=tweepy.API(auth)

# %%
import re

def clean_tweet(tweet):
    '''
    regexp
    '''
    
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\s+)","",tweet).split())

# %%
tweets =api.search('Simple Mobile',count=200)


data = pd.DataFrame(data=[clean_tweet(tweet.text) for tweet in tweets], columns=['Tweets'])


display(data.head(10))

#print(tweets[0].id)
print(tweets[0].created_at)
#print(tweets[0].source)
#print(tweets[0].favorite_count)
#print(tweets[0].retweet_count)
#print(tweets[0].geo)
#print(tweets[0].coordinate)
#print(tweets[0].entities)
# Out:
#                                               Tweets
# 0  Ce sont les auditeurs et les contrleurs fiscau...
# 1  TMobile upgrading select Simple Choice custome...
# 2  RT TMobile upgrading select Simple Choice cust...
# 3  RT TMobile makes Simple Choice promo data bump...
# 4  RT TMobile upgrading select Simple Choice cust...
# 5  RT I will design modern and flat custom icons ...
# 6  RT 2019 Goals FINISH THE GAME PORTION OF MY GA...
# 7  RT TMobile upgrading select Simple Choice cust...
# 8  2019 Goals FINISH THE GAME PORTION OF MY GALAX...
# 9  FOMO NO MO Never miss updates for Luckyland Sl...
# 2019-03-03 05:56:42

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
test = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = test.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   Ce sont les auditeurs et les contrleurs fiscau...
# 1   TMobile upgrading select Simple Choice custome...
# 2   RT TMobile upgrading select Simple Choice cust...
# 3   RT TMobile makes Simple Choice promo data bump...
# 4   RT TMobile upgrading select Simple Choice cust...
# 5   RT I will design modern and flat custom icons ...
# 6   RT 2019 Goals FINISH THE GAME PORTION OF MY GA...
# 7   RT TMobile upgrading select Simple Choice cust...
# 8   2019 Goals FINISH THE GAME PORTION OF MY GALAX...
# 9   FOMO NO MO Never miss updates for Luckyland Sl...
# 10  TMobile upgrading select Simple Choice custome...
# 11  TMobile upgrading select Simple Choice custome...
# 12       RT Keep your family happy httpstcoATO30lUw02
# 13  Why should a Tata Sky ask customer to send SMS...
# 14  RT TMobile upgrading select Simple Choice cust...
# 15  TMobile upgrading select Simple Choice custome...
# 16  httpstcoOoGrsWUWEvNot sure from reading this i...
# 17  I REALLY admire lean design too I hesitated to...
# 18  Mark Anthony bizzelle 912 east 178street Honey...
# 19  RT My nominations for Golden Kitty 2018 Mobile...
# 20  RT FAQ Registrations for app is very simple Yo...
# 21  MemeMill Simple Meme and GIF maker for mobile ...
# 22  RT Montage is an application for wireless and ...
# 23  Simple Invoice Manager v3610 Invoicing Made Ea...
# 24  httpstco80RAREr0UK Select TMobile Simple Choic...
# 25  MobilePlusCarnival2k19 Tu veux marquer ton car...
# 26  We appreciate you coming in You may be able to...
# 27  got this text On 316 were upgrading your voice...
# 28  RT Follow these simple steps to design and pla...
# 29  These mobile games are invested with ads I can...
# ..                                                ...
# 70  RT How to source on the lesser known sitesTapF...
# 71  Ek taraf dhoni ek tarf modi Kise dekhe Answer ...
# 72  SIMPLE MOBILE AND CELLPHONE REPAIR Follow elec...
# 73  VoltEveHow to connect to a VPN on mobile witho...
# 74  Is there a good simple application for reading...
# 75  RT Chain qPocket Mobile Wallet IntroductionqPo...
# 76  RT Chain We are happy to announce QuarkChain q...
# 77  RT wallet qPocket 20 Thank you so much for sup...
# 78  RT FAQ Registrations for app is very simple Yo...
# 79  RT Bills payment at your fingertipsJust dial 3...
# 80  RT PUBG Mobile How To Kill Zombies Easily Like...
# 81  TIPS MOBILE LIGHTROOMbuat korang yang suka sho...
# 82  In a simple tweet guru jee has explained the o...
# 83  Way to glam up your day with good wears Why no...
# 84  I would like to complain about the ur mobile s...
# 85  A Muslim should have an appropriate simple rin...
# 86  RT Headers I think we should definitely do thi...
# 87  Sadly I believe Gov Sectors and employers are ...
# 88  bravo Ethio Telecomconnectivity and access is ...
# 89  Yuk di download secara GRATIS di Playstore sek...
# 90  RT PUBG Mobile How To Kill Zombies Easily Like...
# 91  RT All the sharing All the reaction GIFs Get 2...
# 92  RT httpstco97l1Ayzi8c Hey guys my friend and I...
# 93  Asambhav ABC Keyboard Android Convenient Easy ...
# 94  Oui pour le paiement a ncessite des SIM rcente...
# 95  RT Tech Do you want to join LightningNetwork b...
# 96  Scuse me Did you say government takeover of th...
# 97  RT Bills payment at your fingertipsJust dial 3...
# 98  Just saw this on Amazon Simple Mobile Samsung ...
# 99  Buy now Just saw this on Amazon Simple Mobile ...
#
#                                              polarity
# 0   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 5   {'neg': 0.0, 'neu': 0.879, 'pos': 0.121, 'comp...
# 6   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 7   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 8   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 9   {'neg': 0.144, 'neu': 0.785, 'pos': 0.071, 'co...
# 10  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 11  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 12  {'neg': 0.0, 'neu': 0.575, 'pos': 0.425, 'comp...
# 13  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 14  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 15  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 16  {'neg': 0.0, 'neu': 0.859, 'pos': 0.141, 'comp...
# 17  {'neg': 0.111, 'neu': 0.627, 'pos': 0.262, 'co...
# 18  {'neg': 0.0, 'neu': 0.92, 'pos': 0.08, 'compou...
# 19  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 20  {'neg': 0.0, 'neu': 0.929, 'pos': 0.071, 'comp...
# 21  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 22  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 23  {'neg': 0.0, 'neu': 0.818, 'pos': 0.182, 'comp...
# 24  {'neg': 0.145, 'neu': 0.855, 'pos': 0.0, 'comp...
# 25  {'neg': 0.0, 'neu': 0.782, 'pos': 0.218, 'comp...
# 26  {'neg': 0.0, 'neu': 0.772, 'pos': 0.228, 'comp...
# 27  {'neg': 0.109, 'neu': 0.891, 'pos': 0.0, 'comp...
# 28  {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'comp...
# 29  {'neg': 0.127, 'neu': 0.873, 'pos': 0.0, 'comp...
# ..                                                ...
# 70  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 71  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 72  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 73  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 74  {'neg': 0.0, 'neu': 0.671, 'pos': 0.329, 'comp...
# 75  {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'comp...
# 76  {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'comp...
# 77  {'neg': 0.0, 'neu': 0.779, 'pos': 0.221, 'comp...
# 78  {'neg': 0.0, 'neu': 0.929, 'pos': 0.071, 'comp...
# 79  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 80  {'neg': 0.208, 'neu': 0.575, 'pos': 0.217, 'co...
# 81  {'neg': 0.124, 'neu': 0.876, 'pos': 0.0, 'comp...
# 82  {'neg': 0.146, 'neu': 0.854, 'pos': 0.0, 'comp...
# 83  {'neg': 0.0, 'neu': 0.649, 'pos': 0.351, 'comp...
# 84  {'neg': 0.114, 'neu': 0.773, 'pos': 0.114, 'co...
# 85  {'neg': 0.153, 'neu': 0.847, 'pos': 0.0, 'comp...
# 86  {'neg': 0.0, 'neu': 0.773, 'pos': 0.227, 'comp...
# 87  {'neg': 0.157, 'neu': 0.843, 'pos': 0.0, 'comp...
# 88  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 89  {'neg': 0.0, 'neu': 0.813, 'pos': 0.187, 'comp...
# 90  {'neg': 0.208, 'neu': 0.575, 'pos': 0.217, 'co...
# 91  {'neg': 0.0, 'neu': 0.713, 'pos': 0.287, 'comp...
# 92  {'neg': 0.0, 'neu': 0.809, 'pos': 0.191, 'comp...
# 93  {'neg': 0.0, 'neu': 0.662, 'pos': 0.338, 'comp...
# 94  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 95  {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'comp...
# 96  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 97  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 98  {'neg': 0.0, 'neu': 0.914, 'pos': 0.086, 'comp...
# 99  {'neg': 0.0, 'neu': 0.922, 'pos': 0.078, 'comp...
#
# [100 rows x 2 columns]
