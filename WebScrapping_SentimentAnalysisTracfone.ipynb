# %% [markdown]
# <a href="https://colab.research.google.com/github/siddu541/Analytics/blob/master/WebScrapping_SentimentAnalysisTracfone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (0.22.0)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.5.3)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.14.6)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2->pandas) (1.11.0)
# Requirement already satisfied: tweepy in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.11.0)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy) (2.18.4)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.6.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.2.0)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.0.1)
# Collecting vaderSentiment
#   Downloading https://files.pythonhosted.org/packages/86/9e/c53e1fc61aac5ee490a6ac5e21b1ac04e55a7c2aba647bb8411c9aadf24e/vaderSentiment-3.2.1-py2.py3-none-any.whl (125kB)
#     100% |████████████████████████████████| 133kB 6.3MB/s
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.2.1

# %%
import tweepy
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd

# %%
consumer_key = 'vQZ6khCOPsDeQkY6md7wywU1n' 
consumer_secret='ojflAdoevAAq7SKpoPEifbDfp1sVQ6IXdqX9ZDt5mxHLAkefq9'
access_token='14244512-RquXQtwuWr2RuhUxXJJE9Udtbt9QbyqExhPledJ9Z'
access_token_secret='7fBPW5uEme6lLZJrejSn7jAsExr86H6Zy5cKMrhfYgJos'

# %%
auth=tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)

api=tweepy.API(auth)

# %%
import re

def clean_tweet(tweet):
    '''
    regexp
    '''
    
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\s+)","",tweet).split())

# %%
tweets =api.search('Tracfone',count=1000)


data = pd.DataFrame(data=[clean_tweet(tweet.text) for tweet in tweets], columns=['Tweets'])


display(data.head(10))

#print(tweets[0].id)
print(tweets[0].created_at)
#print(tweets[0].source)
#print(tweets[0].favorite_count)
#print(tweets[0].retweet_count)
#print(tweets[0].geo)
#print(tweets[0].coordinate)
#print(tweets[0].entities)
# Out:
#                                               Tweets
# 0  No verizon cell phone service in mesa and Apac...
# 1  No verizon cell phone service in mesa and Apac...
# 2  New on ebay Apple iPhone 6s 32GB Space Gray St...
# 3  Tracfone Samsung Galaxy J3 Orbit 4 List Price ...
# 4  Nauman Listen asshole my Tracfone runs out of ...
# 5  httpstcou2gg8BkTdUTracFone Samsung Galaxy J7 C...
# 6  NoContract Plans Starting 7 Per Mo Quality Cel...
# 7  NoContract Plans Starting 7 Per Mo Quality Cel...
# 8  Damn gorgeous Im just getting off work but you...
# 9  Brand New Sealed Apple iPhone 7 32GB Black Tra...
# 2019-03-03 15:36:36

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
test = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = test.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   No verizon cell phone service in mesa and Apac...
# 1   No verizon cell phone service in mesa and Apac...
# 2   New on ebay Apple iPhone 6s 32GB Space Gray St...
# 3   Tracfone Samsung Galaxy J3 Orbit 4 List Price ...
# 4   Nauman Listen asshole my Tracfone runs out of ...
# 5   httpstcou2gg8BkTdUTracFone Samsung Galaxy J7 C...
# 6   NoContract Plans Starting 7 Per Mo Quality Cel...
# 7   NoContract Plans Starting 7 Per Mo Quality Cel...
# 8   Damn gorgeous Im just getting off work but you...
# 9   Brand New Sealed Apple iPhone 7 32GB Black Tra...
# 10  NoContract Plans Starting 7 Per Mo Quality Cel...
# 11  the next older black man with a tracfone who h...
# 12  We have checked and verified your concern That...
# 13  NoContract Plans Starting 7 Per Mo Quality Cel...
# 14                       Time to switch to a tracfone
# 15                        TracFone httpstco4Lbe4WlKA4
# 16  Now its easier than ever to stay close Plans s...
# 17  Data Scientist at TracFone Wireless Miami FL h...
# 18  I dont but my mom is still using an old tracfo...
# 19  NoContract Plans Starting 7 Per Mo Quality Cel...
# 20  NoContract Plans Starting 7 Per Mo Quality Cel...
# 21  NoContract Plans Starting 7 Per Mo Quality Cel...
# 22  NoContract Plans Starting 7 Per Mo Quality Cel...
# 23  Just switched to Tmobile via Tracfone Why no V...
# 24          Tracfone Welcome Video httpstco5Hc5Wy18dv
# 25  Just saw this on Amazon Simple Mobile Samsung ...
# 26  Buy now Just saw this on Amazon Simple Mobile ...
# 27  LG Premier Pro 53 HD 16GB Tracfone w1200 Min T...
# 28  I was a computer addict for a long time now li...
# 29  I hate that kids are so materialistic like I s...
# ..                                                ...
# 70  TracFone Samsung Galaxy J3 Luna Pro 4G LTE Pre...
# 71  Meet Kristy She just came in to get an unlocke...
# 72  NoContract Plans Starting 7 Per Mo Quality Cel...
# 73  Tracfone LG Rebel 4 4G LTE 1 Year of Service w...
# 74  We use Tracfone Check HSN or QVC They usually ...
# 75  Why everyone who go live on Facebook got the m...
# 76     Some of yall never had a TracFone and it shows
# 77  10 of 14 be loved songs written Nightfall remo...
# 78  RT still have my safelink tracfone courtesy of...
# 79  Hello I have an unlocked Pixel 2 XL currently ...
# 80  Tracfone Wireless Prepaid CellPhone Tracfone T...
# 81  I saw the MSRP 199999Not Me SisterIm NOT Payin...
# 82  USA Yooooo pass that I want to play Fortnite m...
# 83  RT CAFFREYUSA Hope all phone carriers are requ...
# 84  Hope all phone carriers are required that thei...
# 85  NoContract Plans Starting 7 Per Mo Quality Cel...
# 86  Were sorry to hear that you are caught in this...
# 87  We apologize for the trouble that you have exp...
# 88  inabox Please chat with us live at httpstcoKN3...
# 89  inabox Try to check the pop up box on this cha...
# 90  inabox Were sorry for the trouble you may have...
# 91  Id say yes I gave in and my son has a cheapo T...
# 92  Monet if i had tracfone wireless my phone bill...
# 93  TracFone Samsung Galaxy J3 Luna Pro 4G LTE Pre...
# 94  Were sorry to hear that To assist you with you...
# 95  My girl had that happen to her twice now once ...
# 96  I cant wait til your mom puts some parental co...
# 97  Setting up WIFI is easy Simply text WIFI to 61...
# 98  NoContract Plans Starting 7 Per Mo Quality Cel...
# 99  RT Net10 LG Rebel 3 4G LTE Prepaid Smartphone ...
#
#                                              polarity
# 0   {'neg': 0.115, 'neu': 0.885, 'pos': 0.0, 'comp...
# 1   {'neg': 0.115, 'neu': 0.885, 'pos': 0.0, 'comp...
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3   {'neg': 0.0, 'neu': 0.824, 'pos': 0.176, 'comp...
# 4   {'neg': 0.0, 'neu': 0.902, 'pos': 0.098, 'comp...
# 5   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 6   {'neg': 0.124, 'neu': 0.73, 'pos': 0.146, 'com...
# 7   {'neg': 0.124, 'neu': 0.73, 'pos': 0.146, 'com...
# 8   {'neg': 0.068, 'neu': 0.589, 'pos': 0.343, 'co...
# 9   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 10  {'neg': 0.124, 'neu': 0.73, 'pos': 0.146, 'com...
# 11  {'neg': 0.162, 'neu': 0.838, 'pos': 0.0, 'comp...
# 12  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 13  {'neg': 0.124, 'neu': 0.73, 'pos': 0.146, 'com...
# 14  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 15  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 16  {'neg': 0.0, 'neu': 0.823, 'pos': 0.177, 'comp...
# 17  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 18  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 19  {'neg': 0.124, 'neu': 0.73, 'pos': 0.146, 'com...
# 20  {'neg': 0.124, 'neu': 0.73, 'pos': 0.146, 'com...
# 21  {'neg': 0.124, 'neu': 0.73, 'pos': 0.146, 'com...
# 22  {'neg': 0.124, 'neu': 0.73, 'pos': 0.146, 'com...
# 23  {'neg': 0.136, 'neu': 0.864, 'pos': 0.0, 'comp...
# 24  {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound...
# 25  {'neg': 0.0, 'neu': 0.914, 'pos': 0.086, 'comp...
# 26  {'neg': 0.0, 'neu': 0.922, 'pos': 0.078, 'comp...
# 27  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 28  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 29  {'neg': 0.151, 'neu': 0.735, 'pos': 0.114, 'co...
# ..                                                ...
# 70  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 71  {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'comp...
# 72  {'neg': 0.124, 'neu': 0.73, 'pos': 0.146, 'com...
# 73  {'neg': 0.11, 'neu': 0.89, 'pos': 0.0, 'compou...
# 74  {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'comp...
# 75  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 76  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 77  {'neg': 0.0, 'neu': 0.837, 'pos': 0.163, 'comp...
# 78  {'neg': 0.0, 'neu': 0.898, 'pos': 0.102, 'comp...
# 79  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 80  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 81  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 82  {'neg': 0.0, 'neu': 0.764, 'pos': 0.236, 'comp...
# 83  {'neg': 0.097, 'neu': 0.688, 'pos': 0.215, 'co...
# 84  {'neg': 0.113, 'neu': 0.751, 'pos': 0.136, 'co...
# 85  {'neg': 0.124, 'neu': 0.73, 'pos': 0.146, 'com...
# 86  {'neg': 0.049, 'neu': 0.71, 'pos': 0.242, 'com...
# 87  {'neg': 0.123, 'neu': 0.727, 'pos': 0.15, 'com...
# 88  {'neg': 0.0, 'neu': 0.887, 'pos': 0.113, 'comp...
# 89  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 90  {'neg': 0.154, 'neu': 0.693, 'pos': 0.153, 'co...
# 91  {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'comp...
# 92  {'neg': 0.148, 'neu': 0.721, 'pos': 0.13, 'com...
# 93  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 94  {'neg': 0.066, 'neu': 0.816, 'pos': 0.117, 'co...
# 95  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 96  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 97  {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'comp...
# 98  {'neg': 0.124, 'neu': 0.73, 'pos': 0.146, 'com...
# 99  {'neg': 0.136, 'neu': 0.723, 'pos': 0.14, 'com...
#
# [100 rows x 2 columns]

# %%
print(data.columns)
data.head(2)
# Out:
# Index(['Tweets', 'polarity'], dtype='object')
#                                               Tweets  \
# 0  New on ebay Apple iPhone 6s 32GB Space Gray St...
# 1  Tracfone Samsung Galaxy J3 Orbit 4 List Price ...
#
#                                             polarity
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1  {'neg': 0.0, 'neu': 0.824, 'pos': 0.176, 'comp...

# %%
print(data.shape)
# Out:
# (100, 2)
