# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (0.22.0)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.5.3)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.14.6)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2->pandas) (1.11.0)
# Requirement already satisfied: tweepy in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.11.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.2.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.6.8)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy) (2.18.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2018.11.29)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Collecting vaderSentiment
#   Downloading https://files.pythonhosted.org/packages/86/9e/c53e1fc61aac5ee490a6ac5e21b1ac04e55a7c2aba647bb8411c9aadf24e/vaderSentiment-3.2.1-py2.py3-none-any.whl (125kB)
#     100% |████████████████████████████████| 133kB 6.1MB/s
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.2.1

# %%
import tweepy
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd

# %%
consumer_key = 'vQZ6khCOPsDeQkY6md7wywU1n' 
consumer_secret='ojflAdoevAAq7SKpoPEifbDfp1sVQ6IXdqX9ZDt5mxHLAkefq9'
access_token='14244512-RquXQtwuWr2RuhUxXJJE9Udtbt9QbyqExhPledJ9Z'
access_token_secret='7fBPW5uEme6lLZJrejSn7jAsExr86H6Zy5cKMrhfYgJos'

# %%
auth=tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)

api=tweepy.API(auth)

# %%
import re

def clean_tweet(tweet):
    '''
    regexp
    '''
    
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\s+)","",tweet).split())

# %%
tweets =api.search('Straight Talk',count=200)


data = pd.DataFrame(data=[clean_tweet(tweet.text) for tweet in tweets], columns=['Tweets'])


display(data.head(10))

#print(tweets[0].id)
print(tweets[0].created_at)
#print(tweets[0].source)
#print(tweets[0].favorite_count)
#print(tweets[0].retweet_count)
#print(tweets[0].geo)
#print(tweets[0].coordinate)
#print(tweets[0].entities)
# Out:
#                                               Tweets
# 0  RT After the Balakot strikes some straight tal...
# 1  RT So much of the shade white women get is leg...
# 2  RT once a boy i used to talk to dropped a cont...
# 3  RT once a boy i used to talk to dropped a cont...
# 4  RT After the Balakot strikes some straight tal...
# 5  Yall see me face to face but dont talk about h...
# 6  Damn sometimes I literally have to put on a St...
# 7  RT is this straight people talk for calling hi...
# 8  RT 5 No one goes through more shit then a pers...
# 9  RT Surgical Strike on Pakistan loving journali...
# 2019-03-03 05:48:09

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
test = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = test.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT After the Balakot strikes some straight tal...
# 1   RT So much of the shade white women get is leg...
# 2   RT once a boy i used to talk to dropped a cont...
# 3   RT once a boy i used to talk to dropped a cont...
# 4   RT After the Balakot strikes some straight tal...
# 5   Yall see me face to face but dont talk about h...
# 6   Damn sometimes I literally have to put on a St...
# 7   RT is this straight people talk for calling hi...
# 8   RT 5 No one goes through more shit then a pers...
# 9   RT Surgical Strike on Pakistan loving journali...
# 10  RT is this straight people talk for calling hi...
# 11  RT is this straight people talk for calling hi...
# 12  RT The major who violated Geneva Conventions b...
# 13  RT is this straight people talk for calling hi...
# 14  RT After the Balakot strikes some straight tal...
# 15  RT is this straight people talk for calling hi...
# 16  Im tired of letting straight people talk over ...
# 17  I listen like once a month I usually turn it o...
# 18  RT After the Balakot strikes some straight tal...
# 19  RT once a boy i used to talk to dropped a cont...
# 20  RT After the Balakot strikes some straight tal...
# 21  RT We dont talk enough about how RTD straight ...
# 22  RT Surgical Strike on Pakistan loving journali...
# 23  RT once a boy i used to talk to dropped a cont...
# 24  If anyone cares to talk to me on discord No ma...
# 25  RT After the Balakot strikes some straight tal...
# 26  RT once a boy i used to talk to dropped a cont...
# 27  RT is this straight people talk for calling hi...
# 28  RT is this straight people talk for calling hi...
# 29  RT is this straight people talk for calling hi...
# ..                                                ...
# 70  RT is this straight people talk for calling hi...
# 71  RT is this straight people talk for calling hi...
# 72  RT After the Balakot strikes some straight tal...
# 73  RT Straight talkNo one else is for Maymay MayW...
# 74  RT Talk straight Love that shit Havent had it ...
# 75  RT is this straight people talk for calling hi...
# 76  RT After the Balakot strikes some straight tal...
# 77  RT After the Balakot strikes some straight tal...
# 78  RT is this straight people talk for calling hi...
# 79  RT After the Balakot strikes some straight tal...
# 80  RT So much of the shade white women get is leg...
# 81  RT is this straight people talk for calling hi...
# 82  RT Straight talkNo one else is for Maymay MayW...
# 83  RT After the Balakot strikes some straight tal...
# 84  RT is this straight people talk for calling hi...
# 85  Straight talkNo one else is for Maymay MayWard...
# 86  RT After the Balakot strikes some straight tal...
# 87  RT After the Balakot strikes some straight tal...
# 88  Hes never had that put the game away instinct ...
# 89  RT The major who violated Geneva Conventions b...
# 90  RT After the Balakot strikes some straight tal...
# 91  RT After the Balakot strikes some straight tal...
# 92  RT The major who violated Geneva Conventions b...
# 93  RT is this straight people talk for calling hi...
# 94  RT is this straight people talk for calling hi...
# 95  No that would be your dad You must be a faggot...
# 96  RT After the Balakot strikes some straight tal...
# 97  A real American President triggers hysterical ...
# 98  i want to go in my house but if i do i know il...
# 99  RT is this straight people talk for calling hi...
#
#                                              polarity
# 0   {'neg': 0.193, 'neu': 0.734, 'pos': 0.073, 'co...
# 1   {'neg': 0.135, 'neu': 0.865, 'pos': 0.0, 'comp...
# 2   {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'comp...
# 3   {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'comp...
# 4   {'neg': 0.193, 'neu': 0.734, 'pos': 0.073, 'co...
# 5   {'neg': 0.085, 'neu': 0.915, 'pos': 0.0, 'comp...
# 6   {'neg': 0.145, 'neu': 0.753, 'pos': 0.102, 'co...
# 7   {'neg': 0.177, 'neu': 0.665, 'pos': 0.157, 'co...
# 8   {'neg': 0.254, 'neu': 0.667, 'pos': 0.079, 'co...
# 9   {'neg': 0.067, 'neu': 0.759, 'pos': 0.174, 'co...
# 10  {'neg': 0.177, 'neu': 0.665, 'pos': 0.157, 'co...
# 11  {'neg': 0.177, 'neu': 0.665, 'pos': 0.157, 'co...
# 12  {'neg': 0.279, 'neu': 0.604, 'pos': 0.117, 'co...
# 13  {'neg': 0.177, 'neu': 0.665, 'pos': 0.157, 'co...
# 14  {'neg': 0.193, 'neu': 0.734, 'pos': 0.073, 'co...
# 15  {'neg': 0.177, 'neu': 0.665, 'pos': 0.157, 'co...
# 16  {'neg': 0.226, 'neu': 0.7, 'pos': 0.074, 'comp...
# 17  {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'comp...
# 18  {'neg': 0.193, 'neu': 0.734, 'pos': 0.073, 'co...
# 19  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'comp...
# 20  {'neg': 0.193, 'neu': 0.734, 'pos': 0.073, 'co...
# 21  {'neg': 0.0, 'neu': 0.924, 'pos': 0.076, 'comp...
# 22  {'neg': 0.067, 'neu': 0.759, 'pos': 0.174, 'co...
# 23  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'comp...
# 24  {'neg': 0.241, 'neu': 0.594, 'pos': 0.166, 'co...
# 25  {'neg': 0.193, 'neu': 0.734, 'pos': 0.073, 'co...
# 26  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'comp...
# 27  {'neg': 0.177, 'neu': 0.665, 'pos': 0.157, 'co...
# 28  {'neg': 0.177, 'neu': 0.665, 'pos': 0.157, 'co...
# 29  {'neg': 0.177, 'neu': 0.665, 'pos': 0.157, 'co...
# ..                                                ...
# 70  {'neg': 0.177, 'neu': 0.665, 'pos': 0.157, 'co...
# 71  {'neg': 0.177, 'neu': 0.665, 'pos': 0.157, 'co...
# 72  {'neg': 0.193, 'neu': 0.734, 'pos': 0.073, 'co...
# 73  {'neg': 0.0, 'neu': 0.808, 'pos': 0.192, 'comp...
# 74  {'neg': 0.193, 'neu': 0.481, 'pos': 0.326, 'co...
# 75  {'neg': 0.177, 'neu': 0.665, 'pos': 0.157, 'co...
# 76  {'neg': 0.193, 'neu': 0.734, 'pos': 0.073, 'co...
# 77  {'neg': 0.193, 'neu': 0.734, 'pos': 0.073, 'co...
# 78  {'neg': 0.177, 'neu': 0.665, 'pos': 0.157, 'co...
# 79  {'neg': 0.193, 'neu': 0.734, 'pos': 0.073, 'co...
# 80  {'neg': 0.135, 'neu': 0.865, 'pos': 0.0, 'comp...
# 81  {'neg': 0.177, 'neu': 0.665, 'pos': 0.157, 'co...
# 82  {'neg': 0.0, 'neu': 0.808, 'pos': 0.192, 'comp...
# 83  {'neg': 0.193, 'neu': 0.734, 'pos': 0.073, 'co...
# 84  {'neg': 0.177, 'neu': 0.665, 'pos': 0.157, 'co...
# 85  {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'comp...
# 86  {'neg': 0.193, 'neu': 0.734, 'pos': 0.073, 'co...
# 87  {'neg': 0.193, 'neu': 0.734, 'pos': 0.073, 'co...
# 88  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 89  {'neg': 0.279, 'neu': 0.604, 'pos': 0.117, 'co...
# 90  {'neg': 0.193, 'neu': 0.734, 'pos': 0.073, 'co...
# 91  {'neg': 0.193, 'neu': 0.734, 'pos': 0.073, 'co...
# 92  {'neg': 0.279, 'neu': 0.604, 'pos': 0.117, 'co...
# 93  {'neg': 0.177, 'neu': 0.665, 'pos': 0.157, 'co...
# 94  {'neg': 0.177, 'neu': 0.665, 'pos': 0.157, 'co...
# 95  {'neg': 0.491, 'neu': 0.509, 'pos': 0.0, 'comp...
# 96  {'neg': 0.193, 'neu': 0.734, 'pos': 0.073, 'co...
# 97  {'neg': 0.187, 'neu': 0.813, 'pos': 0.0, 'comp...
# 98  {'neg': 0.134, 'neu': 0.687, 'pos': 0.179, 'co...
# 99  {'neg': 0.177, 'neu': 0.665, 'pos': 0.157, 'co...
#
# [100 rows x 2 columns]
